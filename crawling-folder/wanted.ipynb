# %% [markdown]
# DBA, 빅데이터 엔지니어, 데이터 사이언티스트, 데이터 엔지니어

# %%
url="https://www.wanted.co.kr/api/v4/jobs?1687507695204&country=kr&tag_type_ids=10231&tag_type_ids=1025&tag_type_ids=1024&tag_type_ids=655&locations=all&years=0&years=2&limit=100&offset=1000&job_sort=company.response_rate_order"

# %%
https://www.wanted.co.kr/wd/164973

# %%
import requests

response=requests.get(url)
print(response.status_code)
response.json()
# Out:
# 200
# {'model_status': None,
#  'links': {'prev': '/api/v4/jobs?country=kr&tag_type_ids=10231&tag_type_ids=1025&tag_type_ids=1024&tag_type_ids=655&locations=all&years=0&years=2&limit=100&offset=900&job_sort=company.response_rate_order',
#   'next': None},
#  'is_callable_external_job': False,
#  'data_model': None,
#  'data': None,
#  'is_score': True}

# %%
if not response.json()["data"]:
    print(1)
# Out:
# 1

# %%
url="https://www.wanted.co.kr/api/v4/jobs?1687507695204&country=kr&tag_type_ids=10231&tag_type_ids=1025&tag_type_ids=1024&tag_type_ids=655&locations=all&years=0&years=2&limit=100&offset=0&job_sort=company.response_rate_order"
while 1:
    response=requests.get(url)
    if response.status_code == 200:
        data = response.json()["data"]
        if data:
            print(data)
            break
# Out:
# {'status': 'active', 'reward': {'formatted_total': '100만원', 'formatted_recommender': '50만원', 'formatted_recommendee': '50만원'}, 'is_like': False, 'is_bookmark': False, 'company': {'id': 43703, 'industry_name': '금융', 'application_response_stats': {'avg_rate': 100.0, 'level': 'very_high', 'delayed_count': 0, 'avg_day': None, 'remained_count': 0, 'type': 'applied_reply_done'}, 'name': '큐알에스티에이아이'}, 'title_img': {'origin': 'https://static.wanted.co.kr/images/company/43703/vxf7nxo6vtcnbip0__1080_790.png', 'thumb': 'https://static.wanted.co.kr/images/company/43703/vxf7nxo6vtcnbip0__400_400.png'}, 'compare_country': True, 'due_time': None, 'like_count': 3, 'id': 162876, 'logo_img': {'origin': 'https://static.wanted.co.kr/images/wdes/0_4.122ef2ba.png', 'thumb': 'https://static.wanted.co.kr/images/wdes/0_5.122ef2ba.png'}, 'address': {'country': '한국', 'location': '서울'}, 'matching_score': None, 'position': 'Quant Researcher | 퀀트 데이터 분석가', 'hidden': False, 'score': None, 'category_tags': [{'paren
# ...

# %%
data[0]
# Out:
# {'status': 'active',
#  'reward': {'formatted_total': '100만원',
#   'formatted_recommender': '50만원',
#   'formatted_recommendee': '50만원'},
#  'is_like': False,
#  'is_bookmark': False,
#  'company': {'id': 23371,
#   'industry_name': '전문, 과학기술',
#   'application_response_stats': {'avg_rate': 100.0,
#    'level': 'very_high',
#    'delayed_count': 0,
#    'avg_day': None,
#    'remained_count': 0,
#    'type': 'applied_reply_done'},
#   'name': '스페클립스'},
#  'title_img': {'origin': 'https://static.wanted.co.kr/images/company/23371/kz3bfsjusto4h0sa__1080_790.jpg',
#   'thumb': 'https://static.wanted.co.kr/images/company/23371/kz3bfsjusto4h0sa__400_400.jpg'},
#  'compare_country': True,
#  'due_time': '2023-07-31',
#  'like_count': 0,
#  'id': 164973,
#  'logo_img': {'origin': 'https://static.wanted.co.kr/images/wdes/0_4.872dc089.jpg',
#   'thumb': 'https://static.wanted.co.kr/images/wdes/0_5.872dc089.jpg'},
#  'address': {'country': '한국', 'location': '서울'},
#  'matching_score': None,
# ...

# %%
[{"company_name" :i["company"]["name"],
  "due_time" :i["due_time"],
  "thumb" : i["logo_img"]["thumb"],
  "address" : i["address"],
  "position" : i["position"]} for i in data]
# Out:
# [{'company_name': '스페클립스',
#   'due_time': '2023-07-31',
#   'thumb': 'https://static.wanted.co.kr/images/wdes/0_5.872dc089.jpg',
#   'address': {'country': '한국', 'location': '서울'},
#   'position': '[병역특례 전문연구요원] Computer Vision 엔지니어'},
#  {'company_name': '큐알에스티에이아이',
#   'due_time': None,
#   'thumb': 'https://static.wanted.co.kr/images/wdes/0_5.122ef2ba.png',
#   'address': {'country': '한국', 'location': '서울'},
#   'position': 'Quant Researcher | 퀀트 데이터 분석가'},
#  {'company_name': '몰로코',
#   'due_time': None,
#   'thumb': 'https://static.wanted.co.kr/images/wdes/0_5.d3828878.png',
#   'address': {'country': '한국', 'location': '서울'},
#   'position': 'Machine Learning Engineer (전문연구요원)'},
#  {'company_name': '몰로코',
#   'due_time': None,
#   'thumb': 'https://static.wanted.co.kr/images/wdes/0_5.d3828878.png',
#   'address': {'country': '한국', 'location': '서울'},
#   'position': 'Machine Learning Engineer (산업기능요원)'},
#  {'company_name': '아토리서치',
#   'due_time': None,
# ...

# %%
소프트웨어엔지니어
"https://www.wanted.co.kr/wdlist/518/10110?country=kr&job_sort=company.response_rate_order&years=0&years=2&locations=all"
파이썬개발자
"https://www.wanted.co.kr/wdlist/518/899?country=kr&job_sort=company.response_rate_order&years=0&years=2&locations=all"
데이터엔지니어
"https://www.wanted.co.kr/wdlist/518/655?country=kr&job_sort=company.response_rate_order&years=0&years=2&locations=all"
데이터사이언티스트
"https://www.wanted.co.kr/wdlist/518/1024?country=kr&job_sort=company.response_rate_order&years=0&years=2&locations=all"
빅데이터엔지니어
"https://www.wanted.co.kr/wdlist/518/1025?country=kr&job_sort=company.response_rate_order&years=0&years=2&locations=all"
DBA
"https://www.wanted.co.kr/wdlist/518/10231?country=kr&job_sort=company.response_rate_order&years=0&years=2&locations=all"

# %%
keywords = ["sw", "ict", "it", "db", "부문", "보안", "정보", "인프라", "infra",
            "통신", "네트워크", "network", "data", "데이터", "db", "backend", "be",
            "백엔드", "server", "서버", "fe", "frontend", "프론트엔드", "프론트 엔드",
            "전산", "sw", "software", "소프트웨어", "개발", "시스템", "system", "dba",
            "신입사원", "cloud", "클라우드", "aws", "gcp", "컴퓨터", "스마일게이트", "엔지니어",
            "engineer", "s/w", "웹", "앱", "web", "app", "dx", "cns", "은행", "공채",
            "안드로이드", "임베디드", "php", "블록체인", "blockchain", "bi", "net"]

# %%
/usr/lib/jvm/java-11-openjdk-amd64

# %%
words="clea한Ranc/e"
print(words.lower())
# Out:
# clea한ranc/e

# %%
sudo systemctl start elasticsearch.service
